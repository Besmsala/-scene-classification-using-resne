# %%
import os
import torch
import numpy as np
from torch import nn
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, models
from PIL import Image
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
import torch.nn.functional as F

# %%
from google.colab import drive
import zipfile
import os


# Remount Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install rarfile
# Out:
# Collecting rarfile
#   Downloading rarfile-4.2-py3-none-any.whl.metadata (4.4 kB)
# Downloading rarfile-4.2-py3-none-any.whl (29 kB)
# Installing collected packages: rarfile
# Successfully installed rarfile-4.2

# %%
import rarfile

rar_file_path = '/content/drive/MyDrive/ASAL NWPU DATA/DATA.rar'  # Path to the RAR file
extract_to = '/content/drive/MyDrive/ASAL NWPU DATA/'  # Path to extract everything

# List the contents of the RAR file to check its structure (optional)
with rarfile.RarFile(rar_file_path) as rf:
    for f in rf.infolist():
        print(f.filename)

# Extract everything from the RAR archive
with rarfile.RarFile(rar_file_path) as rf:
    rf.extractall(extract_to)

print("Extraction of the entire RAR file complete!")
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# NWPU-RESISC45_split_val_only/train/wetland/wetland_494.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_495.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_496.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_497.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_498.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_499.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_500.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_501.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_502.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_503.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_504.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_505.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_506.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_507.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_508.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_509.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_510.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_511.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_512.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_513.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_514.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_515.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_516.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_517.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_518.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_519.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_520.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_521.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_522.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_523.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_524.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_525.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_526.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_528.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_529.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_534.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_535.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_536.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_537.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_538.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_539.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_540.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_542.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_543.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_544.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_545.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_546.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_548.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_550.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_551.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_552.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_553.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_554.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_555.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_556.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_557.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_558.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_559.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_561.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_562.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_563.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_564.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_565.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_566.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_567.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_568.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_569.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_570.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_571.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_572.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_573.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_575.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_576.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_577.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_579.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_580.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_581.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_582.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_583.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_584.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_585.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_586.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_587.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_589.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_590.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_591.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_592.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_593.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_594.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_595.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_596.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_597.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_598.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_599.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_600.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_601.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_602.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_603.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_604.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_605.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_606.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_607.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_608.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_609.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_610.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_611.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_612.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_614.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_615.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_616.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_617.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_618.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_619.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_620.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_621.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_622.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_623.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_624.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_625.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_626.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_627.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_628.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_629.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_630.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_632.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_633.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_634.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_636.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_637.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_639.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_640.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_641.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_642.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_643.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_644.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_645.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_646.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_647.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_650.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_651.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_653.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_654.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_655.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_656.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_657.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_658.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_660.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_661.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_662.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_663.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_666.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_667.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_668.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_669.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_670.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_671.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_673.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_674.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_675.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_677.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_678.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_679.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_680.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_682.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_683.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_684.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_686.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_687.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_688.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_689.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_690.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_691.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_692.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_693.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_694.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_695.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_696.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_697.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_698.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_699.jpg
# NWPU-RESISC45_split_val_only/train/wetland/wetland_700.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_006.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_008.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_009.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_024.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_027.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_032.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_041.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_055.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_066.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_076.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_087.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_090.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_092.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_094.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_095.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_102.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_103.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_106.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_115.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_122.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_142.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_148.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_149.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_153.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_164.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_168.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_184.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_192.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_200.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_227.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_229.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_231.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_234.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_237.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_248.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_255.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_264.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_265.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_268.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_270.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_276.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_277.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_278.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_288.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_293.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_299.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_300.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_301.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_304.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_319.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_325.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_336.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_339.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_341.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_345.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_358.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_371.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_374.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_383.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_384.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_395.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_396.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_399.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_401.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_412.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_418.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_420.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_423.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_426.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_434.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_451.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_458.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_465.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_468.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_479.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_485.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_499.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_500.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_525.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_528.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_533.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_538.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_542.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_556.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_562.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_570.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_575.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_576.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_577.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_612.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_618.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_630.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_634.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_658.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_661.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_663.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_671.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_672.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_673.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_676.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_679.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_681.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_692.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_695.jpg
# NWPU-RESISC45_split_val_only/val/airplane/airplane_696.jpg
# NWPU-RESISC45_split_val_only/val/airport/airport_003.jpg
# NWPU-RESISC45_split_val_only/val/airport/airport_007.jpg
# NWPU-RESISC45_split_val_only/val/airport/airport_010.jpg
# NWPU-RESISC45_split_val_only/val/airport/airport_012.jpg
# NWPU-RESISC45_split_val_only/val/airport/airport_022.jpg
# NWPU-RESISC45_split_val_only/val/airport/airport_024.jpg
# NWPU-RESISC45_split_val_only/val/airport/airport_026.jpg
# NWPU-RESISC45_split_val_only/val/airport/airport_034.jpg
# NWPU-RESISC45_split_val_only/val/airport/airport_038.jpg
# NWPU-RESISC45_split_val_only/val/airport/airport_039.jpg
# NWPU-RESISC45_split_val_only/val/airport/airport_040.jpg
# NWPU-RESISC45_split_val_only/val/airport/airport_042.jpg
# NWPU-RESISC45_split_val_only/val/airport/airport_044.jpg
# NWPU-RESISC45_split_val_only/val/airport/airport_050.jpg
# NWPU-RESISC45_split_val_only/val/airport/airport_052.jpg
# NWPU-RESISC45_split_val_only/val/airport/airport_057.jpg
# NWPU-RESISC45_split_val_only/val/airport/airport_064.jpg
# NWPU-RESISC45_split_val_only/val/airport/airport_066.jpg
# NWPU-RESISC45_split_val_only/val/airport/airport_072.jpg
# NWPU-RESISC45_split_val_only/val/airport/airport
# NWPU-RESISC45_split_val_only/train/golf_course/
# NWPU-RESISC45_split_val_only/train/ground_track_field/
# NWPU-RESISC45_split_val_only/train/harbor/
# NWPU-RESISC45_split_val_only/train/industrial_area/
# NWPU-RESISC45_split_val_only/train/intersection/
# NWPU-RESISC45_split_val_only/train/island/
# NWPU-RESISC45_split_val_only/train/lake/
# NWPU-RESISC45_split_val_only/train/meadow/
# NWPU-RESISC45_split_val_only/train/medium_residential/
# NWPU-RESISC45_split_val_only/train/mobile_home_park/
# NWPU-RESISC45_split_val_only/train/mountain/
# NWPU-RESISC45_split_val_only/train/overpass/
# NWPU-RESISC45_split_val_only/train/palace/
# NWPU-RESISC45_split_val_only/train/parking_lot/
# NWPU-RESISC45_split_val_only/train/railway/
# NWPU-RESISC45_split_val_only/train/railway_station/
# NWPU-RESISC45_split_val_only/train/rectangular_farmland/
# NWPU-RESISC45_split_val_only/train/river/
# NWPU-RESISC45_split_val_only/train/roundabout/
# NWPU-RESISC45_split_val_only/train/runway/
# NWPU-RESISC45_split_val_only/train/sea_ice/
# NWPU-RESISC45_split_val_only/train/ship/
# NWPU-RESISC45_split_val_only/train/snowberg/
# NWPU-RESISC45_split_val_only/train/sparse_residential/
# NWPU-RESISC45_split_val_only/train/stadium/
# NWPU-RESISC45_split_val_only/train/storage_tank/
# NWPU-RESISC45_split_val_only/train/tennis_court/
# NWPU-RESISC45_split_val_only/train/terrace/
# NWPU-RESISC45_split_val_only/train/thermal_power_station/
# NWPU-RESISC45_split_val_only/train/wetland/
# NWPU-RESISC45_split_val_only/val/airplane/
# NWPU-RESISC45_split_val_only/val/airport/
# NWPU-RESISC45_split_val_only/val/baseball_diamond/
# NWPU-RESISC45_split_val_only/val/basketball_court/
# NWPU-RESISC45_split_val_only/val/beach/
# NWPU-RESISC45_split_val_only/val/bridge/
# NWPU-RESISC45_split_val_only/val/chaparral/
# NWPU-RESISC45_split_val_only/val/church/
# NWPU-RESISC45_split_val_only/val/circular_farmland/
# NWPU-RESISC45_split_val_only/val/cloud/
# NWPU-RESISC45_split_val_only/val/commercial_area/
# NWPU-RESISC45_split_val_only/val/dense_residential/
# NWPU-RESISC45_split_val_only/val/desert/
# NWPU-RESISC45_split_val_only/val/forest/
# NWPU-RESISC45_split_val_only/val/freeway/
# NWPU-RESISC45_split_val_only/val/golf_course/
# NWPU-RESISC45_split_val_only/val/ground_track_field/
# NWPU-RESISC45_split_val_only/val/harbor/
# NWPU-RESISC45_split_val_only/val/industrial_area/
# NWPU-RESISC45_split_val_only/val/intersection/
# NWPU-RESISC45_split_val_only/val/island/
# NWPU-RESISC45_split_val_only/val/lake/
# NWPU-RESISC45_split_val_only/val/meadow/
# NWPU-RESISC45_split_val_only/val/medium_residential/
# NWPU-RESISC45_split_val_only/val/mobile_home_park/
# NWPU-RESISC45_split_val_only/val/mountain/
# NWPU-RESISC45_split_val_only/val/overpass/
# NWPU-RESISC45_split_val_only/val/palace/
# NWPU-RESISC45_split_val_only/val/parking_lot/
# NWPU-RESISC45_split_val_only/val/railway/
# NWPU-RESISC45_split_val_only/val/railway_station/
# NWPU-RESISC45_split_val_only/val/rectangular_farmland/
# NWPU-RESISC45_split_val_only/val/river/
# NWPU-RESISC45_split_val_only/val/roundabout/
# NWPU-RESISC45_split_val_only/val/runway/
# NWPU-RESISC45_split_val_only/val/sea_ice/
# NWPU-RESISC45_split_val_only/val/ship/
# NWPU-RESISC45_split_val_only/val/snowberg/
# NWPU-RESISC45_split_val_only/val/sparse_residential/
# NWPU-RESISC45_split_val_only/val/stadium/
# NWPU-RESISC45_split_val_only/val/storage_tank/
# NWPU-RESISC45_split_val_only/val/tennis_court/
# NWPU-RESISC45_split_val_only/val/terrace/
# NWPU-RESISC45_split_val_only/val/thermal_power_station/
# NWPU-RESISC45_split_val_only/val/wetland/
# NWPU-RESISC45_split_val_only/train/
# NWPU-RESISC45_split_val_only/val/
# NWPU-RESISC45_split_val_only/
# Extraction of the entire RAR file complete!

# %%
# Custom Dataset class
class ImageFolderDataset(Dataset):
    def __init__(self, root_dir, transform=None):
        self.root_dir = root_dir
        self.transform = transform
        self.classes = sorted(os.listdir(root_dir))
        self.class_to_idx = {cls: idx for idx, cls in enumerate(self.classes)}
        self.images = self._load_images()

    def _load_images(self):
        images = []
        for cls in self.classes:
            class_dir = os.path.join(self.root_dir, cls)
            for img_name in os.listdir(class_dir):
                images.append((os.path.join(class_dir, img_name), self.class_to_idx[cls]))
        return images

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        img_path, label = self.images[idx]
        image = Image.open(img_path).convert('RGB')
        if self.transform:
            image = self.transform(image)
        return image, label

# %%
# Test-time augmentation (center + corners with horizontal flips)
def tta_augment(image):
    crop_size = 224
    crops = []
    # Center crop
    crops.append(transforms.functional.center_crop(image, crop_size))
    # Corner crops
    crops.append(transforms.functional.crop(image, 0, 0, crop_size, crop_size))  # top-left
    crops.append(transforms.functional.crop(image, 0, image.size[1] - crop_size, crop_size, crop_size))  # top-right
    crops.append(transforms.functional.crop(image, image.size[0] - crop_size, 0, crop_size, crop_size))  # bottom-left
    crops.append(transforms.functional.crop(image, image.size[0] - crop_size, image.size[1] - crop_size, crop_size, crop_size))  # bottom-right
    # Horizontal flips
    flips = [transforms.functional.hflip(crop) for crop in crops]
    crops.extend(flips)
    return crops

# Feature extraction using pre-trained CNN
def extract_features(model, dataloader, device):
    model.eval()
    features = []
    labels = []
    for inputs, targets in dataloader:
        inputs = inputs.to(device)
        with torch.no_grad():
            # Extract 4096-dimensional features from FC layer
            fc_features = model(inputs)
            # Apply ReLU activation
            fc_features = F.relu(fc_features)
            features.append(fc_features.cpu().numpy())
            labels.append(targets.cpu().numpy())
    return np.vstack(features), np.hstack(labels)

# %%
# Data augmentation and normalization
data_transforms = {
    'train': transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'val': transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}

# %%
# Load datasets
data_dir = '/content/drive/MyDrive/ASAL NWPU DATA/NWPU-RESISC45_split_val_only'
image_datasets = {x: ImageFolderDataset(os.path.join(data_dir, x), data_transforms[x])
                  for x in ['train', 'val']}
dataloaders = {x: DataLoader(image_datasets[x], batch_size=32, shuffle=True, num_workers=4)
               for x in ['train', 'val']}
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val']}
class_names = image_datasets['train'].classes

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(

# %%
# Load pre-trained CNN and remove the last FC layers
def create_feature_extractor():
    model = models.vgg16(pretrained=True)
    model.classifier = nn.Sequential(*list(model.classifier.children())[:-1])  # Remove the last FC layer
    model = model.to(device)
    return model

# Train a Linear SVM with extracted features
def train_svm(features, labels):
    scaler = StandardScaler()
    features = scaler.fit_transform(features)
    svm = SVC(kernel='linear')
    svm.fit(features, labels)
    return svm, scaler

# Testing and evaluation with SVM
def test_svm(svm, scaler, features, labels):
    features = scaler.transform(features)
    predictions = svm.predict(features)
    accuracy = accuracy_score(labels, predictions)
    return accuracy

# %% [markdown]
# use gan

# %%
    num_classes = len(class_names)

    # Step 1: Create feature extractor model
    model = create_feature_extractor()

    # Step 2: Extract features for training and validation sets
    train_features, train_labels = extract_features(model, dataloaders['train'], device)
    val_features, val_labels = extract_features(model, dataloaders['val'], device)

    # Step 3: Train a Linear SVM
    svm, scaler = train_svm(train_features, train_labels)

    # Step 4: Evaluate on validation set
    val_accuracy = test_svm(svm, scaler, val_features, val_labels)
    print(f'Validation Accuracy: {val_accuracy:.4f}')
# Out:
# Validation Accuracy: 0.8201

# %% [markdown]
# ##  Improved : Using a deep learning pretrained model as our classifier in addition to sub image augmentation

# %% [markdown]
# **Differences from the last approach:**
#
#
# *Current Approach:* Fine-tunes the entire pre-trained model with basic augmentations.
#
#
# *Previous Approach:* Used the pre-trained model as a feature extractor and trained a separate SVM classifier on the extracted features.

# %%
import torch
import torch.nn as nn
from torchvision import models

# Define a function to load a pre-trained model and modify it for fine-tuning
def create_model(model_name, num_classes):
    if model_name == 'resnet':
        model = models.resnet50(weights=models.ResNet50_Weights.DEFAULT)  # Load ResNet50 with pre-trained weights
        # Modify the final fully connected layer (fc) to match the number of classes
        in_features = model.fc.in_features
        model.fc = nn.Linear(in_features, num_classes)

    elif model_name == 'vgg':
        model = models.vgg16(weights=models.VGG16_Weights.DEFAULT)  # Load VGG16 with pre-trained weights
        # Modify the classifier for VGG
        in_features = model.classifier[6].in_features
        model.classifier[6] = nn.Linear(in_features, num_classes)

    elif model_name == 'densenet':
        model = models.densenet121(weights=models.DenseNet121_Weights.DEFAULT)  # Load DenseNet121 with pre-trained weights
        # Modify the classifier for DenseNet
        in_features = model.classifier.in_features
        model.classifier = nn.Linear(in_features, num_classes)

    else:
        raise ValueError("Model name should be 'resnet', 'vgg', or 'densenet'")

    return model

# Function to load the model and perform training/validation
def main(model_name, num_classes, train_dataset, val_dataset):
    # Load the model
    model = create_model(model_name, num_classes)
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model = model.to(device)

    # Define loss and optimizer
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=0.0001)

    # DataLoaders
    train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=32, shuffle=True)
    val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=32, shuffle=False)

    # Training and Validation loop
    num_epochs = 10
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        correct = 0
        total = 0

        # Training loop
        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

        train_accuracy = 100 * correct / total
        print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {running_loss/len(train_loader):.4f}, Train Accuracy: {train_accuracy:.2f}%")

        # Validation loop
        model.eval()
        correct = 0
        total = 0
        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs)
                _, predicted = torch.max(outputs, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()

        val_accuracy = 100 * correct / total
        print(f"Validation Accuracy after Epoch {epoch+1}: {val_accuracy:.2f}%")

# Example usage:
train_dir = '/content/drive/MyDrive/ASAL NWPU DATA/NWPU-RESISC45_split_val_only/train'
val_dir = '/content/drive/MyDrive/ASAL NWPU DATA/NWPU-RESISC45_split_val_only/val'

# Define transformations and load datasets
transform = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

train_dataset = datasets.ImageFolder(train_dir, transform=transform)
val_dataset = datasets.ImageFolder(val_dir, transform=transform)

# Call main function with 'resnet'
main('resnet', num_classes=45, train_dataset=train_dataset, val_dataset=val_dataset)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-11ad3fa6.pth" to /root/.cache/torch/hub/checkpoints/resnet50-11ad3fa6.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 145MB/s]
# Epoch [1/10], Loss: 0.7715, Train Accuracy: 80.57%
# Validation Accuracy after Epoch 1: 93.12%
# Epoch [2/10], Loss: 0.1769, Train Accuracy: 94.34%
# Validation Accuracy after Epoch 2: 94.31%
# Epoch [3/10], Loss: 0.0871, Train Accuracy: 97.38%
# Validation Accuracy after Epoch 3: 94.98%
# Epoch [4/10], Loss: 0.0606, Train Accuracy: 98.16%
# Validation Accuracy after Epoch 4: 94.35%
# Epoch [5/10], Loss: 0.0539, Train Accuracy: 98.34%
# Validation Accuracy after Epoch 5: 94.24%
# Epoch [6/10], Loss: 0.0430, Train Accuracy: 98.67%
# Validation Accuracy after Epoch 6: 93.69%
# Epoch [7/10], Loss: 0.0366, Train Accuracy: 98.91%
# Validation Accuracy after Epoch 7: 94.54%
# Epoch [8/10], Loss: 0.0372, Train Accuracy: 98.82%
# Validation Accuracy after Epoch 8: 94.84%
# Epoch [9/10], Loss: 0.0307, Train Accuracy: 99.10%
# Validation Accuracy after Epoch 9: 94.92%
# Epoch [10/10], Loss: 0.0298, Train Accuracy: 99.09%
# Validation Accuracy after Epoch 10: 94.60%

# %% [markdown]
# **Differences from the last approach:**
#
#
# *Current Approach:* Fine-tunes the entire pre-trained model with 10 sub-image complex augmentations.
#
#
# *Previous Approach:* Fine-tunes the entire pre-trained model with basic augmentations.

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cpu')

# %%
torch.cuda.empty_cache()

# %%
# Call main function with 'resnet'
trained_model, best_model_path = main('vgg', num_classes=45, train_dataset=train_dataset, val_dataset=val_dataset)
# Out:
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.cache/torch/hub/checkpoints/vgg16-397923af.pth
# 100%|██████████| 528M/528M [00:04<00:00, 123MB/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-30f243aee293> in <cell line: 142>()
#     140
#     141 # Call main function with 'resnet'
# --> 142 trained_model, best_model_path = main('vgg', num_classes=45, train_dataset=train_dataset, val_dataset=val_dataset)
#
# <ipython-input-6-30f243aee293> in main(model_name, num_classes, train_dataset, val_dataset)
#      88             outputs = model(inputs)
#      89             loss = criterion(outputs, labels)
# ---> 90             loss.backward()
#      91             optimizer.step()
#      92
#
# /usr/local/lib/python3.10/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     519                 inputs=inputs,
#     520             )
# --> 521         torch.autograd.backward(
#     522             self, gradient, retain_graph, create_graph, inputs=inputs
#     523         )
#
# /usr/local/lib/python3.10/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     287     # some Python versions print out the first line of a multi-line function
#     288     # calls in the traceback and some print out the last line
# --> 289     _engine_run_backward(
#     290         tensors,
#     291         grad_tensors_,
#
# /usr/local/lib/python3.10/dist-packages/torch/autograd/graph.py in _engine_run_backward(t_outputs, *args, **kwargs)
#     766         unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     767     try:
# --> 768         return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     769             t_outputs, *args, **kwargs
#     770         )  # Calls into the C++ engine to run the backward pass
#
# KeyboardInterrupt:

# %% [markdown]
# ##TTA augmentation approach :

# %%
import torch
import torch.nn as nn
from torchvision import models, transforms, datasets
import matplotlib.pyplot as plt

# Define the Test-Time Augmentation function
def tta_augment(image):
    crop_size = 224
    crops = []
    # Center crop
    crops.append(transforms.functional.center_crop(image, crop_size))
    # Corner crops
    crops.append(transforms.functional.crop(image, 0, 0, crop_size, crop_size))  # top-left
    crops.append(transforms.functional.crop(image, 0, image.size[1] - crop_size, crop_size, crop_size))  # top-right
    crops.append(transforms.functional.crop(image, image.size[0] - crop_size, 0, crop_size, crop_size))  # bottom-left
    crops.append(transforms.functional.crop(image, image.size[0] - crop_size, image.size[1] - crop_size, crop_size, crop_size))  # bottom-right
    # Horizontal flips
    flips = [transforms.functional.hflip(crop) for crop in crops]
    crops.extend(flips)
    return crops


# Function to save the model with the best validation accuracy
def save_best_model(model, path):
    torch.save(model.state_dict(), path)
    print(f"Saved Best Model to {path}")

# Function to plot training and validation metrics
def plot_metrics(train_losses, val_accuracies):
    plt.figure(figsize=(12, 5))

    # Plot training loss
    plt.subplot(1, 2, 1)
    plt.plot(range(1, len(train_losses) + 1), train_losses, label='Train Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title('Training Loss')
    plt.legend()

    # Plot validation accuracy
    plt.subplot(1, 2, 2)
    plt.plot(range(1, len(val_accuracies) + 1), val_accuracies, label='Validation Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy (%)')
    plt.title('Validation Accuracy')
    plt.legend()

    plt.tight_layout()
    plt.show()

# Function to apply TTA during validation
def apply_tta(model, loader, device):
    model.eval()
    all_preds = []
    all_labels = []
    with torch.no_grad():
        for inputs, labels in loader:
            inputs, labels = inputs.to(device), labels.to(device)
            preds = torch.zeros(len(labels), num_classes).to(device)
            crops = [tta_augment(transform(img)) for img in inputs]

            for crop_set in crops:
                crop_tensor = torch.stack([transforms.ToTensor()(crop) for crop in crop_set])
                crop_tensor = crop_tensor.to(device)
                outputs = model(crop_tensor)
                preds += torch.mean(outputs, dim=0)

            preds /= len(crops)
            _, predicted = torch.max(preds, 1)
            all_preds.extend(predicted.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    return all_preds, all_labels

# Function to load the model and perform training/validation
def main(model_name, num_classes, train_dataset, val_dataset):
    # Load the model
    model = create_model(model_name, num_classes)
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model = model.to(device)

    # Define loss and optimizer
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=0.0001)

    # DataLoaders
    train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=32, shuffle=True)
    val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=32, shuffle=False)

    # Initialize metrics
    train_losses = []
    val_accuracies = []
    best_val_accuracy = 0.0
    best_model_path = 'best_model.pth'

    num_epochs = 10
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        correct = 0
        total = 0

        # Training loop
        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

        train_accuracy = 100 * correct / total
        train_losses.append(running_loss / len(train_loader))
        print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {train_losses[-1]:.4f}, Train Accuracy: {train_accuracy:.2f}%")

        # Validation loop with TTA
        val_preds, val_labels = apply_tta(model, val_loader, device)
        val_accuracy = 100 * sum([p == l for p, l in zip(val_preds, val_labels)]) / len(val_labels)
        val_accuracies.append(val_accuracy)
        print(f"Validation Accuracy after Epoch {epoch+1}: {val_accuracy:.2f}%")

        # Save the model with the best validation accuracy
        if val_accuracy > best_val_accuracy:
            best_val_accuracy = val_accuracy
            save_best_model(model, best_model_path)

    plot_metrics(train_losses, val_accuracies)
    return model, best_model_path

# Example usage
train_dir = '/content/drive/MyDrive/NWPU-RESISC45_split_val_only/train'
val_dir = '/content/drive/MyDrive/NWPU-RESISC45_split_val_only/val'

# Define transformations and load datasets
transform = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

train_dataset = datasets.ImageFolder(train_dir, transform=transform)
val_dataset = datasets.ImageFolder(val_dir, transform=transform)

# Call main function with 'densenet'
trained_model, best_model_path = main('densenet', num_classes=45, train_dataset=train_dataset, val_dataset=val_dataset)
